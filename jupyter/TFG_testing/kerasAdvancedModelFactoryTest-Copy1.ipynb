# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from financial.momentum.models.kerasAdvanced import KerasAdvancedModelFactory2
from financial.momentum.experiment.modelExperiment import ModelExperimentFactory
# Out:
# 2025-07-04 13:39:38.662949: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-04 13:39:38.926209: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-04 13:39:42.332193: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os
from dotenv import load_dotenv
from financial.momentum.utilities import find_dotenv
import financial.data as fd
from financial.io.file.cache import FileCache
import pandas as pd

# %%
load_dotenv(dotenv_path=find_dotenv())

cache = os.environ["CACHE"]
model = os.environ["MODEL"]
print(model)
print(os.environ["DATA"])
datastore = fd.CachedDataStore(path=os.environ["DATA"], cache=FileCache(cache_path=cache+"/"))
print(datastore)
# Out:
# /home/manidmt/Universidad/TFG/OTRI/models/keras
# /home/manidmt/Universidad/TFG/OTRI/data
# CachedDataStore with 946 data sources [cache stats: {'size': 0, 'hit': 0, 'miss': 0, 'write': 0, 'read': 0, 'update': 0}]

# %%
factory = KerasAdvancedModelFactory2()

# %% [markdown]
# ## Single ticker

# %%
config = {
    "mode": "global",  
    "datastore": datastore,
    "ticker": "^GSPC",
    "model_factory": factory,
    "name": "lstm_test_gspc_1",
    "start_year": "2000-01-01",
    "end_year": "2023-12-31",
    "lookahead": 20,
    "horizon": 90,
    "model_params": {
        "architecture": "lstm",  # <--- lo importante aquí
        "topology": {
            "layers": [32,16],
            "activation": {
                "hidden": "tanh",
                "output": "linear"
            }
        },
        "optimization": {
            "optimizer": "adam",
            "loss": "mean_squared_error",
            "metrics": ["mae"],
            "epochs": 20,  # para pruebas iniciales
            "batch_size": 32,
            "validation_split": 0.1
        }
    }
}

# %%
experiment = ModelExperimentFactory.create_experiment(config)
experiment.run()
print(experiment.predictions)
# Out:
# lstm architecture selected for model lstm_test_gspc_1.2016-01-01
# → Entrenando modelo lstm_test_gspc_1.2016-01-01 con 3935 muestras
# Architecture: mlp
# Fitting model lstm_test_gspc_1.2016-01-01 with architecture mlp
# Epoch 1/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0541
# Epoch 2/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0042
# Epoch 3/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 4/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 5/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 6/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 7/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 8/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0026
# Epoch 9/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 10/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 11/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 12/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0026
# Epoch 13/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 14/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 15/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 16/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 17/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 18/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 19/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 20/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 21/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0027
# Epoch 22/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0028
# Epoch 23/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 24/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 25/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 26/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 27/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0026
# Epoch 28/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0026
# Epoch 29/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0027
# Epoch 30/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 31/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 32/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 33/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 34/300
#  7/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 experiment = ModelExperimentFactory.create_experiment(config)
# ----> 2 experiment.run()
#       3 print(experiment.predictions)
#
# File ~/Universidad/TFG/OTRI/src/financial/momentum/experiment/modelExperiment.py:104, in GlobalModelExperiment.run(self)
#      90 #model = self.model_factory.create_model(self.name, self.hyperparameters, self.datastore)
#      91 #print(model.to_xml_string())
#      92
#      93 # print(df.columns)
#      95 cross_validation = labevaluation.WalkForwardCrossValidation ( self.name,
#      96                                                             self.hyperparameters,
#      97                                                             self.features,
#    (...)
#     102                                                             save_path=os.environ["CACHE"],
#     103                                                             save_intermediate_results=False)
# --> 104 cross_validation.run()
#     106 # Final model
#     108 self.train = cross_validation.experiment_results['train'][self.ticker]
#
# File ~/Universidad/TFG/OTRI/src/financial/lab/evaluation.py:113, in ModelBuildingTask.run(self)
#     108 '''
#     109 Task execution
#     110 '''
#     111 start_time = time.time()
# --> 113 self.model = self.build()
#     115 end_time = time.time()
#     116 self.running_time = end_time - start_time
#
# File ~/Universidad/TFG/OTRI/src/financial/lab/evaluation.py:319, in WalkForwardCrossValidation.build(self)
#     317 # Train model
#     318 print(f"Architecture: {model.architecture}")
# --> 319 model.fit(X_train, y_train)
#     321 # Save model
#     322 if self.save_intermediate_results:
#
# File ~/Universidad/TFG/OTRI/src/financial/momentum/models/kerasAdvanced.py:43, in KerasAdvancedModel.fit(self, X_train, y_train)
#      41 print(f"Fitting model {self.name} with architecture {self.architecture}")
#      42 if self.architecture == "mlp":
# ---> 43     return super().fit(X_train, y_train)
#      45 X_train = self.reshape_input(X_train)
#      46 if isinstance(y_train, (pd.Series, pd.DataFrame)):
#
# File ~/Universidad/TFG/OTRI/src/financial/model.py:728, in KerasModel.fit(self, X_train, y_train)
#     721 hyperparameters = self.optimizer_hyperparameters()
#     723 self.model.compile(
#     724     optimizer = hyperparameters['optimizer'],
#     725     loss = hyperparameters['loss'],
#     726     metrics = hyperparameters['metrics'])
# --> 728 self.model.fit(
#     729     X_train, y_train,
#     730     epochs = hyperparameters['epochs'],
#     731     batch_size = hyperparameters['batch_size'],
#     732     validation_split = hyperparameters['validation_split'],
#     733     callbacks = hyperparameters['stop'])
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(step, logs)
#     379     if self.stop_training:
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:220, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     216 def function(iterator):
#     217     if isinstance(
#     218         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219     ):
# --> 220         opt_outputs = multi_step_on_iterator(iterator)
#     221         if not opt_outputs.has_value():
#     222             raise StopIteration
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/Universidad/TFG/OTRI/my_env/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
absolute_predictions = experiment.reconstruct_absolute_predictions_from_relative()
print(absolute_predictions)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl

mpl.rc('figure', figsize=(16, 9))
mpl.__version__
style.use('ggplot')
def plot_series(series: list[pd.Series], start_date: str=None, end_date: str=None):
    for i, serie in enumerate(series):
            linewidth = 1.0  # Grosor de línea predeterminado
            if i == 0:  # Si es la primera serie en la lista (índice 0)
                linewidth = 3.0  # Grosor de línea mayor
            serie[start_date:end_date].plot(linewidth=linewidth)

# %%
data = datastore.get_data("^GSPC", "2000-01-01", "2023-12-31")

# %%
plot_series([data, absolute_predictions])

# %%
plot_series([data, absolute_predictions], "2020-01-01", "2020-12-31")

# %%
from financial.model import Model
model_r = model_svr = Model.from_file('lstm_test_gspc', path = os.environ["MODEL"])
predictions_r = model_r.get_data(datastore, start_index="2000-01-01", end_index="2023-12-31")
print(predictions_r)

# %% [markdown]
# ## Multiple tickers

# %%
config = {
    "mode": "global",
    "datastore": datastore,
    "ticker": ["^GSPC", "^TNX"],  # múltiples tickers
    "model_factory": factory,
    "name": "lstm_test_multiticker",
    "start_year": "2000-01-01",
    "end_year": "2023-12-31",
    "lookahead": 20,
    "horizon": 90,
    "model_params": {
        "architecture": "lstm",
        "topology": {
            "layers": [32, 16],
            "activation": {
                "hidden": "tanh",
                "output": "linear"
            }
        },
        "optimization": {
            "optimizer": "adam",
            "loss": "mean_squared_error",
            "metrics": ["mae"],
            "epochs": 20,
            "batch_size": 32,
            "validation_split": 0.1
        }
    }
}

# %%
experiment = ModelExperimentFactory.create_experiment(config)
experiment.run()
print(experiment.predictions)

# %%
absolute_predictions = experiment.reconstruct_absolute_predictions_from_relative()
print(absolute_predictions)

# %%
plot_series([data, absolute_predictions])

# %%
plot_series([data, absolute_predictions], "2020-01-01", "2020-12-31")

# %% [markdown]
# ## Metrics
# SVR: 8455 MSE=712.6578 RMSE=26.6957 MAE=15.6174 MAPE=0.0096 R² = 0.9994 (**1990 - 2024**)
#
#     TRAIN: n=62696 MSE=0.0002 RMSE=0.0134 MAE=0.0092 MAPE=0.6531
#
#     TEST: n=13579 MSE=0.0032 RMSE=0.0563 MAE=0.0392 MAPE=2.4412

# %%
target = data[90 + 20:]
print(target.size)
from financial.lab.experiment import Experiment
from sklearn.metrics import r2_score

# %%
def reconstruct(predictions):
    reconstructed_final = data / (1 + predictions)
    return reconstructed_final.shift(20).dropna()

# %%
absolute_predictions_r = reconstruct(predictions_r)
metrics_single = Experiment("lstm_test_gspc", absolute_predictions_r, target)
r2 = r2_score(target, absolute_predictions_r)

print("GLOBAL:")
print(f"n={metrics_single.samples()} MSE={metrics_single.MSE():.4f} RMSE={metrics_single.RMSE():.4f} MAE={metrics_single.MAE():.4f} MAPE={metrics_single.MAPE():.4f} R² = {r2:.4f}")

# %%
metrics_multiple = Experiment("lstm_test_gspc_multiple", absolute_predictions, target)
r2 = r2_score(target, absolute_predictions)

print("GLOBAL:")
print(f"n={metrics_multiple.samples()} MSE={metrics_multiple.MSE():.4f} RMSE={metrics_multiple.RMSE():.4f} MAE={metrics_multiple.MAE():.4f} MAPE={metrics_multiple.MAPE():.4f} R² = {r2:.4f}")

print("TRAIN: ")
results = experiment.train
print(f"n={results.samples()} MSE={results.MSE():.4f} RMSE={results.RMSE():.4f} MAE={results.MAE():.4f} MAPE={results.MAPE():.4f}")

print("TEST: ")
results = experiment.test
print(f"n={results.samples()} MSE={results.MSE():.4f} RMSE={results.RMSE():.4f} MAE={results.MAE():.4f} MAPE={results.MAPE():.4f}")
