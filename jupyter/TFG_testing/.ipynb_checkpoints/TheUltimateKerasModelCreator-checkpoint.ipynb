# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import requests
import os

TELEGRAM_TOKEN = "8083975934:AAEFXz0ja40Z470mmZSqGej7g6p80Kt6wh0"  # o ponlo directamente como string
TELEGRAM_CHAT_ID = "1030345806"

def send_telegram_message(message):
    url = f"https://api.telegram.org/bot{TELEGRAM_TOKEN}/sendMessage"
    payload = {
        "chat_id": TELEGRAM_CHAT_ID,
        "text": message
    }
    try:
        response = requests.post(url, data=payload)
        if response.status_code != 200:
            print("❌ Error en la respuesta de Telegram:")
            print(response.status_code)
            print(response.text)
        else:
            print("✅ Mensaje enviado correctamente.")
    except Exception as e:
        print(f"❌ No se pudo enviar el mensaje de Telegram: {e}")

# %%
from financial.momentum.models.kerasAdvanced import KerasAdvancedModelFactory
from financial.momentum.experiment.modelExperiment import ModelExperimentFactory
import os
from dotenv import load_dotenv
from financial.momentum.utilities import find_dotenv
from financial.momentum.utilities import metrics
import financial.data as fd
from financial.io.file.cache import FileCache
import pandas as pd
from financial.lab.experiment import Experiment
from sklearn.metrics import r2_score
from financial.model import Model

import tensorflow as tf
from keras import backend as K
import gc

def reset_gpu():
    K.clear_session()
    tf.keras.backend.clear_session()
    gc.collect()

# %%
load_dotenv(dotenv_path=find_dotenv())

cache_path = os.environ["CACHE"]
model_path = os.environ["MODEL"]
print(model_path)
print(os.environ["DATA"])
datastore = fd.CachedDataStore(path=os.environ["DATA"], cache=FileCache(cache_path=cache_path+"/"))
print(datastore)
# Out:
# /home/manidmt/TFG/OTRI/models/keras
# /home/manidmt/TFG/OTRI/data
# CachedDataStore with 960 data sources [cache stats: {'size': 0, 'hit': 0, 'miss': 0, 'write': 0, 'read': 0, 'update': 0}]

# %%
start_date = "1990-01-01"
end_date = "2025-06-30"

# %%
import os
import pickle

def store_results(ticker: str, model_name: str, predictions: pd.Series):

    base_name = f"model-momentum-{model_name}-{ticker}"

    # Guardar .pkl para Wrapper
    with open(os.path.join(cache_path, base_name), "wb") as f:
        pickle.dump(predictions, f)
    print("Prediciones guardadas pickle")
    # Guardar .csv para inspección y web
    predictions.to_csv(os.path.join(model_path, model_name + "_preds.csv"))
    print("Prediciones guardadas csv")

# %%
data = datastore.get_data(ticker, start_date, end_date)
print(data)
target = data[90 + 20:]
print(target.size)
# Out:
# 2020-01-02    3257.850098
# 2020-01-03    3234.850098
# 2020-01-06    3246.280029
# 2020-01-07    3237.179932
# 2020-01-08    3253.050049
#                  ...
# 2025-06-24    6092.180000
# 2025-06-25    6092.160000
# 2025-06-26    6141.020000
# 2025-06-27    6173.070000
# 2025-06-30    6204.950000
# Name: ^GSPC, Length: 1381, dtype: float64
# 1271

# %%
factory = KerasAdvancedModelFactory()

# %%
from itertools import product

# Arquitecturas a probar
#architectures = ["cnn"]
architectures = ["rnn", "lstm", "cnn", "cnn2d", "transformer"]

# Hiperparámetros a explorar
layer_option = [64, 32]
activation = ["relu"]
batch_size = 32
epochs = 10

def ticker_single_models(ticker):

    data = datastore.get_data(ticker, start_date, end_date)    
    target = data[90 + 20:]
    
    for arch in architectures:
        name = f"{arch}_{ticker}_{end_date[:4]}_single"
        path = model_path + "/" + name

        try:
            if Model.from_file(name, path=os.environ["MODEL"]):
                print(f"Modelo {name} ya existe. Saltando...")
                send_telegram_message(f"Modelo {name} ya existe. Saltando...")
                continue
        except FileNotFoundError:
            print(f"📂 Modelo {name} no existe. Procediendo a entrenar...")
            send_telegram_message(f"Modelo {name} no existe. Procediendo a entrenar...")

        config = {
            "mode": "global",  
            "datastore": datastore,
            "ticker": ticker,
            "model_factory": factory,
            "name": name,
            "start_year": start_date,
            "end_year": end_date,
            "lookahead": 20,
            "horizon": 90,
            "model_params": {
                "architecture": arch,
                "topology": {
                    "layers": layer_option,
                    "activation": {
                        "hidden": activation,
                        "output": "linear"
                    }
                },
                "optimization": {
                    "optimizer": "adam",
                    "loss": "mean_squared_error",
                    "metrics": ["mae"],
                    "epochs": epochs,
                    "batch_size": batch_size,
                    "validation_split": 0.1
                }
            }
        }

        try:
            print("RUNNING MODEL:")
            experiment = ModelExperimentFactory.create_experiment(config)
            experiment.run()
            print("METRICS:")
            preds = experiment.reconstruct_absolute_predictions_from_relative()
            store_results(ticker, name, preds)
            send_telegram_message("Resultados guardados")
            metrics(experiment, preds, target, model_path)
            send_telegram_message("Metricas guardadas")
            reset_gpu()
        except Exception as e:
            print(f"Falló el modelo {name}: {e}")

# %%
ticker_single_models("GOOG")
ticker_single_models("BLK")
ticker_single_models("BAM")
# Out:
# 📂 Modelo cnn_GOOG_2025_single no existe. Procediendo a entrenar...
# ✅ Mensaje enviado correctamente.
# RUNNING MODEL:
# Architecture: cnn
# Epoch 1/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0016 - loss: 0.9947
# Epoch 2/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.2330
# Epoch 3/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0016 - loss: 0.0729
# Epoch 4/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0016 - loss: 0.0638
# Epoch 5/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0016 - loss: 0.0230
# Epoch 6/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 2.4260e-04 - loss: 0.0130
# Epoch 7/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0025 - loss: 0.0118
# Epoch 8/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 5.1128e-04 - loss: 0.0063
# Epoch 9/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 6.8490e-04 - loss: 0.0057
# Epoch 10/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0025 - loss: 0.0056
# Epoch 11/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 5.1128e-04 - loss: 0.0056
# Epoch 12/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0016 - loss: 0.0056
# Epoch 13/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 6.8490e-04 - loss: 0.0056
# Epoch 14/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0012 - loss: 0.0058
# Epoch 15/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 6.8490e-04 - loss: 0.0058
# Epoch 16/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 2.4260e-04 - loss: 0.0064
# Epoch 17/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 5.1128e-04 - loss: 0.0055
# Epoch 18/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 5.1128e-04 - loss: 0.0057
# Epoch 19/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 9.0191e-04 - loss: 0.0056
# Epoch 20/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0025 - loss: 0.0057
# Epoch 21/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0016 - loss: 0.0057
# Epoch 22/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 6.8490e-04 - loss: 0.0058
# Epoch 23/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 5.1128e-04 - loss: 0.0058
# Epoch 24/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0012 - loss: 0.0056
# Epoch 25/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0012 - loss: 0.0056
# Epoch 26/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 5.1128e-04 - loss: 0.0057
# Epoch 27/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0025 - loss: 0.0058
# Epoch 28/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0012 - loss: 0.0055
# Epoch 29/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 6.8490e-04 - loss: 0.0058
# Epoch 30/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 5.1128e-04 - loss: 0.0056
# Epoch 31/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0016 - loss: 0.0058
# Epoch 32/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0025 - loss: 0.0054
# Epoch 33/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0025 - loss: 0.0054
# Epoch 34/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 3.6661e-04 - loss: 0.0055
# Epoch 35/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 5.1128e-04 - loss: 0.0055
# Epoch 36/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0016 - loss: 0.0057
# Epoch 37/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 6.8490e-04 - loss: 0.0058
# Epoch 38/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 9.0191e-04 - loss: 0.0054
# Epoch 39/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0012 - loss: 0.0056
# Epoch 40/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 6.8490e-04 - loss: 0.0060
# Epoch 41/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 9.0191e-04 - loss: 0.0057
# Epoch 42/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0025 - loss: 0.0055
# Epoch 43/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 9.0191e-04 - loss: 0.0056
# Epoch 44/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0016 - loss: 0.0057
# Epoch 45/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0025 - loss: 0.0061
# Epoch 46/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 3.6661e-04 - loss: 0.0065
# Epoch 47/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0012 - loss: 0.0057
# Epoch 48/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 5.1128e-04 - loss: 0.0054
# Epoch 49/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 6.8490e-04 - loss: 0.0057
# Epoch 50/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 9.0191e-04 - loss: 0.0058
# Epoch 51/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 3.6661e-04 - loss: 0.0060
# Epoch 52/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0012 - loss: 0.0056
# Epoch 53/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0012 - loss: 0.0056
# Epoch 54/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 6.8490e-04 - loss: 0.0055
# Epoch 55/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 9.0191e-04 - loss: 0.0060
# Epoch 56/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0012 - loss: 0.0063
# Epoch 57/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 3.6661e-04 - loss: 0.0057
# Epoch 58/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 5.1128e-04 - loss: 0.0055
# Epoch 59/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 6.8490e-04 - loss: 0.0057
# Epoch 60/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0025 - loss: 0.0057
# Epoch 61/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 6.8490e-04 - loss: 0.0057
# Epoch 62/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 5.1128e-04 - loss: 0.0057
# Epoch 63/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0012 - loss: 0.0056
# Epoch 64/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 9.0191e-04 - loss: 0.0051
# Epoch 65/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 9.0191e-04 - loss: 0.0052
# Epoch 66/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0016 - loss: 0.0053
# Epoch 67/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0012 - loss: 0.0055
# Epoch 68/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0016 - loss: 0.0048
# Epoch 69/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 9.0191e-04 - loss: 0.0050
# Epoch 70/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0012 - loss: 0.0053
# Epoch 71/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0012 - loss: 0.0054
# Epoch 72/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0016 - loss: 0.0054
# Epoch 73/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 6.8490e-04 - loss: 0.0061
# Epoch 74/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0025 - loss: 0.0060
# Epoch 75/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0012 - loss: 0.0057
# Epoch 76/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0025 - loss: 0.0055
# Epoch 77/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 5.1128e-04 - loss: 0.0052
# Epoch 78/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 2.4260e-04 - loss: 0.0054
# Epoch 79/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0025 - loss: 0.0058
# Epoch 80/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 5.1128e-04 - loss: 0.0054
# Epoch 81/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 3.6661e-04 - loss: 0.0057
# Epoch 82/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0016 - loss: 0.0052
# Epoch 83/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 9.0191e-04 - loss: 0.
300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 3.4802e-04 - loss: 0.0057
# Epoch 252/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 2.6664e-04 - loss: 0.0054
# Epoch 253/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 2.6664e-04 - loss: 0.0054
# Epoch 254/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.9430e-04 - loss: 0.0054
# Epoch 255/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 3.4802e-04 - loss: 0.0052
# Epoch 256/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 3.4802e-04 - loss: 0.0061
# Epoch 257/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 6.7974e-04 - loss: 0.0064
# Epoch 258/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 2.6664e-04 - loss: 0.0066
# Epoch 259/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 5.4953e-04 - loss: 0.0070
# Epoch 260/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0011 - loss: 0.0054
# Epoch 261/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 3.4802e-04 - loss: 0.0088
# Epoch 262/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 6.7974e-04 - loss: 0.0062
# Epoch 263/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 4.4103e-04 - loss: 0.0075
# Epoch 264/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0020 - loss: 0.0069
# Epoch 265/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0020 - loss: 0.0056
# Epoch 266/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 8.4250e-04 - loss: 0.0054
# Epoch 267/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 8.4250e-04 - loss: 0.0056
# Epoch 268/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.2920e-04 - loss: 0.0063
# Epoch 269/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.9430e-04 - loss: 0.0054
# Epoch 270/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0011 - loss: 0.0063
# Epoch 271/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 2.6664e-04 - loss: 0.0055
# Epoch 272/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 2.6664e-04 - loss: 0.0057
# Epoch 273/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.9430e-04 - loss: 0.0063
# Epoch 274/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 5.4953e-04 - loss: 0.0063
# Epoch 275/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 4.4103e-04 - loss: 0.0056
# Epoch 276/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 5.4953e-04 - loss: 0.0058
# Epoch 277/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 5.4953e-04 - loss: 0.0061
# Epoch 278/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0011 - loss: 0.0059
# Epoch 279/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 6.7974e-04 - loss: 0.0060
# Epoch 280/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0011 - loss: 0.0054
# Epoch 281/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 4.4103e-04 - loss: 0.0052
# Epoch 282/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 3.4802e-04 - loss: 0.0057
# Epoch 283/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 3.4802e-04 - loss: 0.0082
# Epoch 284/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 6.7974e-04 - loss: 0.0104
# Epoch 285/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 6.7974e-04 - loss: 0.0062
# Epoch 286/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0014 - loss: 0.0057
# Epoch 287/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 2.6664e-04 - loss: 0.0075
# Epoch 288/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 3.4802e-04 - loss: 0.0057
# Epoch 289/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 6.7974e-04 - loss: 0.0052
# Epoch 290/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 3.4802e-04 - loss: 0.0052
# Epoch 291/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 3.4802e-04 - loss: 0.0051
# Epoch 292/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.2920e-04 - loss: 0.0057
# Epoch 293/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 4.4103e-04 - loss: 0.0054
# Epoch 294/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 5.4953e-04 - loss: 0.0054
# Epoch 295/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 2.6664e-04 - loss: 0.0055
# Epoch 296/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 5.4953e-04 - loss: 0.0059
# Epoch 297/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 8.4250e-04 - loss: 0.0062
# Epoch 298/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.9430e-04 - loss: 0.0054
# Epoch 299/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 6.7974e-04 - loss: 0.0061
# Epoch 300/300
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 2.6664e-04 - loss: 0.0062
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# METRICS:
# Prediciones guardadas pickle
# Prediciones guardadas csv
# ✅ Mensaje enviado correctamente.
# GLOBAL:
# n=1270 MSE=110.1869 RMSE=10.4970 MAE=8.5731 MAPE=0.0661 R² = 0.8930
# TRAIN:
# n=916 MSE=0.0073 RMSE=0.0857 MAE=0.0718 MAPE=3.0655
# TEST:
# n=374 MSE=0.0109 RMSE=0.1042 MAE=0.0935 MAPE=3.8072
#
# Métricas guardadas exitosamente en: /home/manidmt/TFG/OTRI/models/keras/cnn_GOOG_2025_single_metrics.json
# ✅ Mensaje enviado correctamente.

# %%
index_tickers = [
    "^GSPC",          # S&P 500
    "^IXIC",          # Nasdaq
    "^IBEX",          # Ibex 35
    "AMZN",
    "TSLA",
    "GOOG",
    "BAM",
    "BLK",
]

# %%
for ticker in index_tickers:
    ticker_single_models(ticker)
# Out:
# 📂 Modelo cnn_^GSPC_2025_single no existe. Procediendo a entrenar...
# ✅ Mensaje enviado correctamente.
# RUNNING MODEL:
# Architecture: cnn
# Epoch 1/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0000e+00 - loss: 0.5610
# Epoch 2/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.1146
# Epoch 3/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0403
# Epoch 4/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0305
# Epoch 5/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0078
# Epoch 6/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0061
# Epoch 7/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.0042
# Epoch 8/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 9/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 10/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 11/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 12/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0018
# Epoch 13/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 14/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 15/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 16/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 17/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 18/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 19/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 20/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 21/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 22/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 23/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 24/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 25/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 26/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 27/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 28/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 29/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 30/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 31/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 32/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 33/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 34/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 35/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 36/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 37/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 38/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 39/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 40/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 41/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 42/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 43/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 44/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 45/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 46/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 47/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 48/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 49/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 50/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 51/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0027
# Epoch 52/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0024
# Epoch 53/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 54/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 55/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 56/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 57/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 58/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 59/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 60/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 61/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 62/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 63/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 64/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 65/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 66/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 67/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 68/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 69/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 70/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 71/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 72/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0031
# Epoch 73/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 74/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 75/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 76/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 77/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 78/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 79/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 80/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 81/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 82/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 83/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 84/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 85/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 86/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 87/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 88/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 89/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 90/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 91/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 92/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 93/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 94/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 95/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 96/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 97/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 98/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0019
# Epoch 99/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 100/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 101/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0029
# Epoch 102/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0027
# Epoch 103/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0033
# Epoch 104/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 105/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0029
# Epoch 106/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0027
# Epoch 107/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0021
# Epoch 108/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 109/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0020
# Epoch 110/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0025
# Epoch 111/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0022
# Epoch 112/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0023
# Epoch 113/300
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - loss: 0.0110
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[104], line 2
#       1 for ticker in index_tickers:
# ----> 2     ticker_single_models(ticker)
#
# Cell In[101], line 64, in ticker_single_models(ticker)
#      62 print("RUNNING MODEL:")
#      63 experiment = ModelExperimentFactory.create_experiment(config)
# ---> 64 experiment.run()
#      65 print("METRICS:")
#      66 preds = experiment.reconstruct_absolute_predictions_from_relative()
#
# File ~/TFG/OTRI/src/financial/momentum/experiment/modelExperiment.py:105, in GlobalModelExperiment.run(self)
#      91 #model = self.model_factory.create_model(self.name, self.hyperparameters, self.datastore)
#      92 #print(model.to_xml_string())
#      93
#      94 # print(df.columns)
#      96 cross_validation = labevaluation.WalkForwardCrossValidation ( self.name,
#      97                                                             self.hyperparameters,
#      98                                                             self.features,
#    (...)
#     103                                                             save_path=os.environ["CACHE"],
#     104                                                             save_intermediate_results=False)
# --> 105 cross_validation.run()
#     107 # Final model
#     109 self.train = cross_validation.experiment_results['train'][self.ticker]
#
# File ~/TFG/OTRI/src/financial/lab/evaluation.py:113, in ModelBuildingTask.run(self)
#     108 '''
#     109 Task execution
#     110 '''
#     111 start_time = time.time()
# --> 113 self.model = self.build()
#     115 end_time = time.time()
#     116 self.running_time = end_time - start_time
#
# File ~/TFG/OTRI/src/financial/lab/evaluation.py:322, in WalkForwardCrossValidation.build(self)
#     319 # print(f"→ Entrenando modelo {self.experiment_id}.{date} con {len(X_train)} muestras")
#     320 # Train model
#     321 print(f"Architecture: {model.architecture}")
# --> 322 model.fit(X_train, y_train)
#     324 # Save model
#     325 if self.save_intermediate_results:
#
# File ~/TFG/OTRI/src/financial/momentum/models/kerasAdvanced.py:298, in ConvolutionalModel.fit(self, X_train, y_train)
#     290 optimizer_params = self.optimizer_hyperparameters()
#     292 self.model.compile(
#     293     loss=optimizer_params["loss"],
#     294     optimizer=optimizer_params["optimizer"],
#     295     metrics=optimizer_params["metrics"]
#     296 )
# --> 298 self.model.fit(
#     299     X_train, y_train,
#     300     epochs=optimizer_params["epochs"],
#     301     batch_size=optimizer_params["batch_size"],
#     302     validation_split=optimizer_params["validation_split"],
#     303     callbacks=[optimizer_params["stop"]] if optimizer_params["stop"] else None
#     304 )
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(step, logs)
#     379     if self.stop_training:
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:220, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     216 def function(iterator):
#     217     if isinstance(
#     218         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219     ):
# --> 220         opt_outputs = multi_step_on_iterator(iterator)
#     221         if not opt_outputs.has_value():
#     222             raise StopIteration
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~/miniconda3/envs/tfg_gpu/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
