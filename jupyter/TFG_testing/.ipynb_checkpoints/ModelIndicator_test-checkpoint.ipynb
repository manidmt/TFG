# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import financial.data as fd
import financial.model as fm
import financial.portfolio as fp
import financial.strategies.simulation as fss
from financial.io.file.cache import FileCache
from financial.io.cache import AppendStrategy
from financial.io.file.model import FileModelProvider

import os
from dotenv import load_dotenv
from financial.momentum.utilities import find_dotenv
from financial.momentum.experiment.modelExperiment import ModelExperimentFactory

# %%
load_dotenv(dotenv_path=find_dotenv())

cache = os.environ["CACHE"] + "/"
model = os.environ["MODEL"] + "/"

ds = fd.CachedDataStore(path=os.environ["DATA"], cache=FileCache(cache_path=cache))
mp = FileModelProvider(model_path=model)
mc = fm.ModelCache(ds, mp, cache=FileCache(update_strategy=AppendStrategy(), cache_path=model))

# %%
import financial.lab.models as labmodels
import sklearn.linear_model

class LinearScikitLearnModelFactory (labmodels.ModelFactory):
    '''
    Linear regression Scikit-Learn model factory
    '''
        
    def create_model_from_descriptors(self, 
                                      model_id: str, 
                                      hyperparameters: dict, 
                                      input_descriptor: fd.DataDescriptor, 
                                      output_descriptor: fd.DataDescriptor) -> fm.Model:
        model = sklearn.linear_model.LinearRegression()
        return fm.ScikitLearnModel(model_id, input_descriptor, output_descriptor, model, hyperparameters)
        

factory = LinearScikitLearnModelFactory()

# %%
start_date = "1990-01-01"
end_date = "2023-12-31"
universe_spdr_us = ['XLE', 'XLB', 'XLI', 'XLY', 'XLP', 'XLV', 'XLF', 'XLK', 'XLU', 'XSD'] # XLC XLRE out
for ticker in universe_spdr_us:
    config = {
        "mode": "global",
        "datastore": ds,
        "ticker": ticker,
        "model_factory": factory,
        "name": "scikit-learn_linearRegresion" + "_" + ticker,
        "start_year": start_date,
        "end_year": end_date
    }
    experiment_linear = ModelExperimentFactory.create_experiment(config)
    data = ds.get_data(ticker, start_date, end_date)
    if len(data) < 90:
        print(f"[{ticker}] Skipped: not enough data ({len(data)} rows)")
        continue
    experiment_linear.run()
    print(ticker)
# Out:
# XLE
# XLB
# XLI
# XLY
# XLP
# XLV
# XLF
# XLK
# XLU
# XSD

# %%
from financial.momentum.indicators.modelIndicator import ModelIndicator
simulation_indicator = ModelIndicator("scikit-learn_linearRegression")

# %%
import financial.strategies.allocation as fsa
import financial.strategies.filter as fsf
import financial.strategies.rank as fsr

simulation_filter = fsf.CompositeAssetFilter( [fsf.TopKAssetFilter(k=4), fsf.MinimumValueAssetFilter(threshold=0.0)] )
simulation_allocation = fsa.FixedWeightAllocation(0.10)
simulation_strategy = fsr.AssetRankingStrategy("Simulation", universe_spdr_us, simulation_indicator, simulation_filter, simulation_allocation)
print(simulation_strategy)
# Out:
# Simulation
# - 10 asset universe: ['XLE', 'XLB', 'XLI', 'XLY', 'XLP', 'XLV', 'XLF', 'XLK', 'XLU', 'XSD']
# - Indicator: {'type': 'financial.momentum.indicators.modelIndicator.ModelIndicator'}

# %%
# %%time
import financial.strategies.rebalance as fsrebalance

strategy_simulation = "simulation"
strategy = simulation_strategy
benchmark = fp.BenchmarkPortfolio("^GSPC")
market = ds.get_data("^GSPC")
rebalancing = fsrebalance.MonthlyRebalancingSchedule(-1,market) # +1 first day, -1 last day, +2 second day with 1st day momentum

print("STRATEGY")
print(strategy)
print("BENCHMARK")
print(benchmark)
print("REBALANCING")
print(rebalancing)

simulation = fss.StockStrategySimulation(ds, strategy, rebalancing, market)
simulation.verbose = True  # verbose 41.7s vs. 27s without trading details
simulation_start_year = 2001
simulation_end_year = 2023
simulation.simulate(start_year=simulation_start_year, end_year=simulation_end_year)
# Out:
# STRATEGY
# Simulation
# - 10 asset universe: ['XLE', 'XLB', 'XLI', 'XLY', 'XLP', 'XLV', 'XLF', 'XLK', 'XLU', 'XSD']
# - Indicator: {'type': 'financial.momentum.indicators.modelIndicator.ModelIndicator'}
# BENCHMARK
# ^GSPC(^GSPC)
# REBALANCING
# Rebalancing schedule: Monthly rebalancing on -1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Universidad/TFG/OTRI/src/financial/io/cache.py:89, in DataCache.get_available_data(self, ticker)
#      88 try:
# ---> 89     series = self.cache[ticker]
#      90     self.stats['hit'] += 1
#
# KeyError: 'scikit-learn_linearRegression_XLE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File <timed exec>:20
#
# File ~/Universidad/TFG/OTRI/src/financial/strategies/simulation.py:417, in StockStrategySimulation.simulate(self, start_year, end_year)
#     413 '''
#     414 Strategy simulation
#     415 '''
#     416 # Strategy preparation
# --> 417 self.strategy.evaluate(self.ds)
#     418 # Target portfolios
#     419 self.targets = {}
#
# File ~/Universidad/TFG/OTRI/src/financial/strategies/rank.py:140, in AssetRankingStrategy.evaluate(self, ds, start_date, end_date)
#     131 def evaluate (self, ds: fd.DataStore, start_date: str='1999-12-31', end_date: str=None) -> Dict[str, pd.Series]:
#     132     '''
#     133     Perform asset evaluation.
#     134
#    (...)
#     138     @return: Dictionary of asset evaluations for the specified date range.
#     139     '''
# --> 140     return self.ranking.evaluate(ds,start_date,end_date)
#
# File ~/Universidad/TFG/OTRI/src/financial/strategies/rank.py:48, in AssetRanking.evaluate(self, ds, start_date, end_date)
#      45 valuation = {}
#      47 for ticker in self.universe:
# ---> 48     ticker_data = self.signal.get_data(ds, ticker, start_index=start_date, end_index=end_date) # > 1yr horizon
#      49     valuation[ticker] = ticker_data.dropna()
#      51 self.valuation = valuation
#
# File ~/Universidad/TFG/OTRI/src/financial/strategies/technical/indicator.py:67, in TechnicalIndicator.get_data(self, provider, ticker, start_index, end_index)
#      57 '''
#      58 Returns the values of the technical indicator for the specified ticker
#      59
#    (...)
#      64 :return: Data series with the technical indicator for each day.
#      65 '''
#      66 descriptor = self.get_data_descriptor_for_ticker(ticker)
# ---> 67 series = descriptor.get_data(provider, start_index, end_index)
#      68 return pd.Series(series, name=ticker+"_"+self.__class__.__name__)
#
# File ~/Universidad/TFG/OTRI/src/financial/data.py:314, in Variable.get_data(self, provider, start_index, end_index)
#     313 def get_data(self, provider, start_index=None, end_index=None):
# --> 314     return provider.get_data(self.ticker,start_index,end_index)
#
# File ~/Universidad/TFG/OTRI/src/financial/data.py:215, in CachedDataStore.get_data(self, ticker, start_index, end_index, callback)
#     214 def get_data(self, ticker, start_index=None, end_index=None, callback=None):
# --> 215     return self.cache.get_data(ticker, start_index, end_index, callback=None)
#
# File ~/Universidad/TFG/OTRI/src/financial/io/cache.py:130, in DataCache.get_data(self, ticker, start_index, end_index, callback)
#     128 def get_data(self, ticker, start_index=None, end_index=None, callback=None):
# --> 130     series = self.get_available_data(ticker)
#     132     if not (start_index is None):
#     133         if type(start_index) is str:
#
# File ~/Universidad/TFG/OTRI/src/financial/io/cache.py:96, in DataCache.get_available_data(self, ticker)
#      93     series = self.read(ticker)
#      95     if series is None:
# ---> 96         series = self.get_updated_data(ticker)
#      98     self.cache[ticker] = series
#     100 return series
#
# File ~/Universidad/TFG/OTRI/src/financial/io/cache.py:106, in DataCache.get_updated_data(self, ticker, start_index, end_index, callback)
#     103 def get_updated_data(self, ticker, start_index=None, end_index=None, callback=None):
#     105     if not isinstance(self.update_strategy, NoUpdateStrategy):
# --> 106         series = self.data_store.get_updated_data(ticker, None, end_index, callback)
#     107         series = self.update(ticker,series,end_index)
#     108         return series
#
# File ~/Universidad/TFG/OTRI/src/financial/data.py:207, in CachedDataStore.get_updated_data(self, ticker, start_index, end_index, callback)
#     206 def get_updated_data(self, ticker, start_index=None, end_index=None, callback=None):
# --> 207     return super().get_data(ticker, start_index, end_index, callback)
#
# File ~/Universidad/TFG/OTRI/src/financial/data.py:103, in DataStore.get_data(self, ticker, start_index, end_index, callback)
#     102 def get_data(self, ticker: str, start_index: str=None, end_index: str=None, callback=None) -> pd.Series:
# --> 103     providers = self.get_metadata_providers(ticker)
#     105     if not (start_index is None):
#     106         if type(start_index) is str:
#
# File ~/Universidad/TFG/OTRI/src/financial/data.py:87, in DataStore.get_metadata_providers(self, ticker)
#      84 def get_metadata_providers(self, ticker):
#      85     providers = []
# ---> 87     for data_source in self.metadata.get_providers(ticker):
#      88         providers += self.providers[data_source]
#      90     return providers
#
# File ~/Universidad/TFG/OTRI/src/financial/io/file/metadata.py:82, in FileMetadataStore.get_providers(self, ticker)
#      78 def get_providers(self, ticker):
#      79     '''
#      80     Variable data providers (i.e. a single one)
#      81     '''
# ---> 82     if "providers" in self.metadata[ticker]:
#      83         return self.metadata[ticker]["providers"]
#      84     else:
#
# KeyError: 'scikit-learn_linearRegression_XLE'

# %%
year_returns = simulation.year_returns()

print("\nSTRATEGY RETURNS")
for year in year_returns:
    print(f"{year}: {100*year_returns[year]:6.2f}%")


cumulative = simulation.cumulative_returns(year_returns)

print("\nCUMULATIVE RETURNS")
for year in cumulative:
    print(f"{year}: {100*cumulative[year]:6.2f}%")

# %%
simulation.simulation_year_report()
