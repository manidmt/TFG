# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from financial.momentum.models.kerasAdvanced import KerasAdvancedModelFactory
from financial.momentum.experiment.modelExperiment import ModelExperimentFactory

# %%
import os
from dotenv import load_dotenv
from financial.momentum.utilities import find_dotenv
import financial.data as fd
from financial.io.file.cache import FileCache
import pandas as pd

# %%
load_dotenv(dotenv_path=find_dotenv())

cache = os.environ["CACHE"]
model = os.environ["MODEL"]
print(model)
print(os.environ["DATA"])
datastore = fd.CachedDataStore(path=os.environ["DATA"], cache=FileCache(cache_path=cache+"/"))
print(datastore)
# Out:
# /home/manidmt/Universidad/TFG/OTRI/models/keras
# /home/manidmt/Universidad/TFG/OTRI/data
# CachedDataStore with 946 data sources [cache stats: {'size': 0, 'hit': 0, 'miss': 0, 'write': 0, 'read': 0, 'update': 0}]

# %%
factory = KerasAdvancedModelFactory()

# %%
config = {
    "mode": "global",  # también puedes probar "local"
    "datastore": datastore,
    "ticker": "^GSPC",
    "model_factory": factory,
    "name": "lstm_test_gspc",
    "start_year": "2000-01-01",
    "end_year": "2023-12-31",
    "lookahead": 20,
    "horizon": 90,
    "model_params": {
        "architecture": "lstm",  # <--- lo importante aquí
        "topology": {
            "layers": [32,16],
            "activation": {
                "hidden": "tanh",
                "output": "linear"
            }
        },
        "optimization": {
            "optimizer": "adam",
            "loss": "mean_squared_error",
            "metrics": ["mae"],
            "epochs": 20,  # para pruebas iniciales
            "batch_size": 32,
            "validation_split": 0.1
        }
    }
}

# %%
experiment = ModelExperimentFactory.create_experiment(config)
experiment.run()
print(experiment.predictions)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 experiment = ModelExperimentFactory.create_experiment(config)
# ----> 2 experiment.run()
#       3 print(experiment.predictions)
#
# File ~/Universidad/TFG/OTRI/src/financial/momentum/experiment/modelExperiment.py:99, in GlobalModelExperiment.run(self)
#      85 #model = self.model_factory.create_model(self.name, self.hyperparameters, self.datastore)
#      86 #print(model.to_xml_string())
#      87
#      88 # print(df.columns)
#      90 cross_validation = labevaluation.WalkForwardCrossValidation ( self.name,
#      91                                                             self.hyperparameters,
#      92                                                             self.features,
#    (...)
#      97                                                             save_path=os.environ["CACHE"],
#      98                                                             save_intermediate_results=False)
# ---> 99 cross_validation.run()
#     101 # Final model
#     103 self.train = cross_validation.experiment_results['train'][self.ticker]
#
# File ~/Universidad/TFG/OTRI/src/financial/lab/evaluation.py:113, in ModelBuildingTask.run(self)
#     108 '''
#     109 Task execution
#     110 '''
#     111 start_time = time.time()
# --> 113 self.model = self.build()
#     115 end_time = time.time()
#     116 self.running_time = end_time - start_time
#
# File ~/Universidad/TFG/OTRI/src/financial/lab/evaluation.py:315, in WalkForwardCrossValidation.build(self)
#     312 self.logger.info(str(X_test.shape)+' test set') #y_test.shape
#     314 # Create model
# --> 315 model = self.factory.create_model_from_descriptors(self.experiment_id+'.'+date, self.hyperparameters, self.input_descriptor, self.output_descriptor)
#     317 # Train model
#     318 model.fit(X_train, y_train)
#
# File ~/Universidad/TFG/OTRI/src/financial/momentum/models/kerasAdvanced.py:118, in KerasAdvancedModelFactory.create_model_from_descriptors(self, model_id, hyperparameters, input_descriptor, output_descriptor)
#     113 def create_model_from_descriptors(self,
#     114                                   model_id: str,
#     115                                   hyperparameters: dict,
#     116                                   input_descriptor: fd.DataDescriptor,
#     117                                   output_descriptor: fd.DataDescriptor) -> KerasAdvancedModel:
# --> 118     return KerasAdvancedModel(model_id, input_descriptor, output_descriptor, model=None, hyperparameters=hyperparameters)
#
# File ~/Universidad/TFG/OTRI/src/financial/momentum/models/kerasAdvanced.py:18, in KerasAdvancedModel.__init__(self, name, sources, target, model, hyperparameters)
#      17 def __init__(self, name: str, sources: fd.DataDescriptor, target: fd.DataDescriptor, model: keras.Model=None, hyperparameters: dict=None):
# ---> 18     super().__init__(name, sources, target, model, hyperparameters)
#      19     self.architecture = hyperparameters.get('architecture', 'mlp')
#
# File ~/Universidad/TFG/OTRI/src/financial/model.py:473, in KerasModel.__init__(self, name, sources, target, model, hyperparameters)
#     471     self.hyperparameters['topology'] = self.keras_model_topology()
#     472 else: # i.e. not self.model:
# --> 473     self.model = self.initialize_model()
#
# File ~/Universidad/TFG/OTRI/src/financial/momentum/models/kerasAdvanced.py:70, in KerasAdvancedModel.initialize_model(self)
#      68 def initialize_model(self):
# ---> 70     if self.architecture == "mlp":
#      71         return super().initialize_model()
#      73     layers = self.hyperparameters["topology"]["layers"]
#
# AttributeError: 'KerasAdvancedModel' object has no attribute 'architecture'
